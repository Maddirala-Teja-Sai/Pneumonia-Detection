# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
import matplotlib.pyplot as plt
import seaborn as sns

# --- Configuration ---
DATA_DIR = '/kaggle/input/chest-xray-pneumonia/chest_xray'
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42

# --- Data generators ---
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True
).flow_from_directory(
    os.path.join(DATA_DIR, 'train'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=True,
    seed=SEED
)

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input).flow_from_directory(
    os.path.join(DATA_DIR, 'val'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False,
    seed=SEED
)

test_gen = ImageDataGenerator(preprocessing_function=preprocess_input).flow_from_directory(
    os.path.join(DATA_DIR, 'test'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False,
    seed=SEED
)

# --- Class weights ---
train_labels = train_gen.classes
weights = compute_class_weight('balanced', 
                               classes=np.unique(train_labels), 
                               y=train_labels)
class_weights = dict(enumerate(weights))
print("Class weights:", class_weights)

# --- Model building ---
base = ResNet50(weights='imagenet', include_top=False, input_shape=(*IMG_SIZE, 3))
base.trainable = False

inputs = layers.Input(shape=(*IMG_SIZE, 3))
x = preprocess_input(inputs)
x = base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-3))(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model = models.Model(inputs, outputs)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), 
              loss='binary_crossentropy', 
              metrics=['accuracy'])
model.summary()

# --- Callbacks ---
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6)

# --- Train Phase 1 ---
history1 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=20,
    class_weight=class_weights,
    callbacks=[early_stop, reduce_lr],
    verbose=2
)

# --- Fine-tune Phase 2 ---
base.trainable = True
for layer in base.layers[:-20]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history2 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10,
    class_weight=class_weights,
    callbacks=[early_stop, reduce_lr],
    verbose=2
)

# --- Evaluation ---
test_gen.reset()
y_true = test_gen.classes
y_pred_prob = model.predict(test_gen).flatten()
y_pred = (y_pred_prob > 0.5).astype(int)

print(f"\n✅ Accuracy: {accuracy_score(y_true, y_pred):.4f}")
print(f"🎯 F1 Score: {f1_score(y_true, y_pred):.4f}")
print(f"⭐ Precision: {precision_score(y_true, y_pred):.4f}")
print(f"🔄 Recall: {recall_score(y_true, y_pred):.4f}")
print("\n📋 Classification Report:")
print(classification_report(y_true, y_pred, target_names=['NORMAL', 'PNEUMONIA']))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['NORMAL','PNEUMONIA'], yticklabels=['NORMAL','PNEUMONIA'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# --- Training curves ---
def plot_combined(h1, h2=None):
    acc = h1.history['accuracy'] + (h2.history['accuracy'] if h2 else [])
    val_acc = h1.history['val_accuracy'] + (h2.history['val_accuracy'] if h2 else [])
    loss = h1.history['loss'] + (h2.history['loss'] if h2 else [])
    val_loss = h1.history['val_loss'] + (h2.history['val_loss'] if h2 else [])
    
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Train Acc')
    plt.plot(val_acc, label='Val Acc')
    plt.legend(); plt.title('Accuracy')
    
    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Train Loss')
    plt.plot(val_loss, label='Val Loss')
    plt.legend(); plt.title('Loss')
    plt.show()

plot_combined(history1, history2)
# Out:
# 2025-06-12 11:23:10.776277: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749727390.957928      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749727391.012955      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Class weights: {0: 1.9448173005219984, 1: 0.6730322580645162}
# I0000 00:00:1749727413.471490      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item (GetItem)        │ (None, 224, 224)       │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_1 (GetItem)      │ (None, 224, 224)       │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_2 (GetItem)      │ (None, 224, 224)       │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack (Stack)             │ (None, 224, 224, 3)    │              0 │ get_item[0][0],        │
# │                           │                        │                │ get_item_1[0][0],      │
# │                           │                        │                │ get_item_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 224, 224, 3)    │              0 │ stack[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ resnet50 (Functional)     │ (None, 7, 7, 2048)     │     23,587,712 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 2048)           │              0 │ resnet50[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 512)            │      1,049,088 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 512)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 1)              │            513 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 24,637,313 (93.98 MB)
#  Trainable params: 1,049,601 (4.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749727433.208480     114 service.cc:148] XLA service 0x7c8b78002740 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749727433.209537     114 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1749727434.810957     114 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1749727438.883645     114 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 163/163 - 156s - 955ms/step - accuracy: 0.8691 - loss: 1.0509 - val_accuracy: 0.8750 - val_loss: 0.9515 - learning_rate: 1.0000e-04
# Epoch 2/20
# 163/163 - 91s - 557ms/step - accuracy: 0.9273 - loss: 0.8197 - val_accuracy: 0.9375 - val_loss: 0.7949 - learning_rate: 1.0000e-04
# Epoch 3/20
# 163/163 - 91s - 559ms/step - accuracy: 0.9461 - loss: 0.7108 - val_accuracy: 0.9375 - val_loss: 0.6841 - learning_rate: 1.0000e-04
# Epoch 4/20
# 163/163 - 91s - 556ms/step - accuracy: 0.9490 - loss: 0.6541 - val_accuracy: 1.0000 - val_loss: 0.6152 - learning_rate: 1.0000e-04
# Epoch 5/20
# 163/163 - 91s - 561ms/step - accuracy: 0.9505 - loss: 0.6037 - val_accuracy: 1.0000 - val_loss: 0.5569 - learning_rate: 1.0000e-04
# Epoch 6/20
# 163/163 - 90s - 555ms/step - accuracy: 0.9519 - loss: 0.5659 - val_accuracy: 0.9375 - val_loss: 0.5452 - learning_rate: 1.0000e-04
# Epoch 7/20
# 163/163 - 91s - 558ms/step - accuracy: 0.9517 - loss: 0.5308 - val_accuracy: 1.0000 - val_loss: 0.4704 - learning_rate: 1.0000e-04
# Epoch 8/20
# 163/163 - 90s - 553ms/step - accuracy: 0.9561 - loss: 0.4983 - val_accuracy: 1.0000 - val_loss: 0.4633 - learning_rate: 1.0000e-04
# Epoch 9/20
# 163/163 - 90s - 555ms/step - accuracy: 0.9559 - loss: 0.4711 - val_accuracy: 1.0000 - val_loss: 0.4465 - learning_rate: 1.0000e-04
# Epoch 10/20
# 163/163 - 91s - 559ms/step - accuracy: 0.9640 - loss: 0.4348 - val_accuracy: 1.0000 - val_loss: 0.3969 - learning_rate: 1.0000e-04
# Epoch 11/20
# 163/163 - 91s - 561ms/step - accuracy: 0.9574 - loss: 0.4239 - val_accuracy: 1.0000 - val_loss: 0.3824 - learning_rate: 1.0000e-04
# Epoch 12/20
# 163/163 - 91s - 556ms/step - accuracy: 0.9628 - loss: 0.3978 - val_accuracy: 0.9375 - val_loss: 0.5331 - learning_rate: 1.0000e-04
# Epoch 13/20
# 163/163 - 91s - 559ms/step - accuracy: 0.9613 - loss: 0.3842 - val_accuracy: 1.0000 - val_loss: 0.3379 - learning_rate: 1.0000e-04
# Epoch 14/20
# 163/163 - 91s - 561ms/step - accuracy: 0.9611 - loss: 0.3717 - val_accuracy: 1.0000 - val_loss: 0.3290 - learning_rate: 1.0000e-04
# Epoch 15/20
# 163/163 - 90s - 551ms/step - accuracy: 0.9641 - loss: 0.3496 - val_accuracy: 1.0000 - val_loss: 0.3268 - learning_rate: 1.0000e-04
# Epoch 16/20
# 163/163 - 91s - 556ms/step - accuracy: 0.9599 - loss: 0.3459 - val_accuracy: 1.0000 - val_loss: 0.3105 - learning_rate: 1.0000e-04
# Epoch 17/20
# 163/163 - 92s - 563ms/step - accuracy: 0.9628 - loss: 0.3266 - val_accuracy: 1.0000 - val_loss: 0.2887 - learning_rate: 1.0000e-04
# Epoch 18/20
# 163/163 - 94s - 577ms/step - accuracy: 0.9632 - loss: 0.3201 - val_accuracy: 1.0000 - val_loss: 0.2655 - learning_rate: 1.0000e-04
# Epoch 19/20
# 163/163 - 95s - 582ms/step - accuracy: 0.9620 - loss: 0.3112 - val_accuracy: 1.0000 - val_loss: 0.2611 - learning_rate: 1.0000e-04
# Epoch 20/20
# 163/163 - 94s - 577ms/step - accuracy: 0.9640 - loss: 0.3012 - val_accuracy: 1.0000 - val_loss: 0.2584 - learning_rate: 1.0000e-04
# Epoch 1/10
# 163/163 - 118s - 724ms/step - accuracy: 0.9636 - loss: 0.2950 - val_accuracy: 1.0000 - val_loss: 0.2372 - learning_rate: 1.0000e-05
# Epoch 2/10
# 163/163 - 93s - 572ms/step - accuracy: 0.9712 - loss: 0.2712 - val_accuracy: 1.0000 - val_loss: 0.2273 - learning_rate: 1.0000e-05
# Epoch 3/10
# 163/163 - 93s - 569ms/step - accuracy: 0.9697 - loss: 0.2717 - val_accuracy: 1.0000 - val_loss: 0.2258 - learning_rate: 1.0000e-05
# Epoch 4/10
# 163/163 - 92s - 565ms/step - accuracy: 0.9772 - loss: 0.2529 - val_accuracy: 1.0000 - val_loss: 0.2288 - learning_rate: 1.0000e-05
# Epoch 5/10
# 163/163 - 93s - 568ms/step - accuracy: 0.9774 - loss: 0.2494 - val_accuracy: 1.0000 - val_loss: 0.2074 - learning_rate: 1.0000e-05
# Epoch 6/10
# 163/163 - 92s - 566ms/step - accuracy: 0.9799 - loss: 0.2463 - val_accuracy: 1.0000 - val_loss: 0.2060 - learning_rate: 1.0000e-05
# Epoch 7/10
# 163/163 - 95s - 582ms/step - accuracy: 0.9810 - loss: 0.2403 - val_accuracy: 1.0000 - val_loss: 0.2005 - learning_rate: 1.0000e-05
# Epoch 8/10
# 163/163 - 93s - 569ms/step - accuracy: 0.9808 - loss: 0.2355 - val_accuracy: 1.0000 - val_loss: 0.1982 - learning_rate: 1.0000e-05
# Epoch 9/10
# 163/163 - 92s - 563ms/step - accuracy: 0.9845 - loss: 0.2309 - val_accuracy: 1.0000 - val_loss: 0.1971 - learning_rate: 1.0000e-05
# Epoch 10/10
# 163/163 - 92s - 566ms/step - accuracy: 0.9816 - loss: 0.2312 - val_accuracy: 1.0000 - val_loss: 0.1927 - learning_rate: 1.0000e-05
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 694ms/step
#
# ✅ Accuracy: 0.9151
# 🎯 F1 Score: 0.9320
# ⭐ Precision: 0.9332
# 🔄 Recall: 0.9308
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.89      0.89      0.89       234
#    PNEUMONIA       0.93      0.93      0.93       390
#
#     accuracy                           0.92       624
#    macro avg       0.91      0.91      0.91       624
# weighted avg       0.92      0.92      0.92       624

# %%
#ResNet50-Kaggle
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# --- GPU Setup ---
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"✅ GPU(s): {[gpu.name for gpu in gpus]}")
else:
    print("⚠️ Using CPU")

# --- Config ---
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 10
SEED = 42
DATA_DIR = '/kaggle/input/chest-xray-pneumonia/chest_xray'  # change to actual path in your environment

# --- Load datasets ---
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    os.path.join(DATA_DIR, 'train'),
    label_mode='binary',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    os.path.join(DATA_DIR, 'val'),
    label_mode='binary',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    os.path.join(DATA_DIR, 'test'),
    label_mode='binary',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# --- Prefetch and cache for performance ---
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE).cache()
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE).cache()
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE).cache()

# --- Preprocessing layer for ResNet50 ---
preprocess_layer = layers.Lambda(preprocess_input)

# --- Model Setup ---
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(*IMG_SIZE, 3))
base_model.trainable = False  # Freeze base model

inputs = layers.Input(shape=(*IMG_SIZE, 3))
x = preprocess_layer(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = models.Model(inputs, outputs)

model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()

# --- Train ---
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[early_stop],
    verbose=2
)

# --- Evaluate on test set ---
test_labels = np.concatenate([y for x, y in test_ds], axis=0)
test_images = np.concatenate([x for x, y in test_ds], axis=0)

y_pred_prob = model.predict(test_images).flatten()
y_pred = (y_pred_prob > 0.5).astype(int)

print(f"\n✅ Test Accuracy: {accuracy_score(test_labels, y_pred):.4f}")
print(f"🎯 Test F1 Score: {f1_score(test_labels, y_pred):.4f}")
print("\n📋 Classification Report:")
print(classification_report(test_labels, y_pred, target_names=["NORMAL", "PNEUMONIA"]))

# --- Confusion Matrix ---
cm = confusion_matrix(test_labels, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=["NORMAL", "PNEUMONIA"],
            yticklabels=["NORMAL", "PNEUMONIA"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# --- Plot training history ---
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss')

plt.show()
# Out:
# 2025-06-09 11:57:08.181166: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749470228.421905      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749470228.498984      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ✅ GPU(s): ['/physical_device:GPU:0']
# Found 5216 files belonging to 2 classes.
# I0000 00:00:1749470251.138254      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 16 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lambda (Lambda)                      │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │           2,049 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,589,761 (89.99 MB)
#  Trainable params: 2,049 (8.00 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749470269.077686     102 service.cc:148] XLA service 0x7f9a44003c40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749470269.078569     102 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1749470270.957587     102 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1749470274.913724     102 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 163/163 - 43s - 266ms/step - accuracy: 0.7358 - loss: 0.5773 - val_accuracy: 0.5625 - val_loss: 0.6141
# Epoch 2/10
# 163/163 - 7s - 42ms/step - accuracy: 0.8487 - loss: 0.3515 - val_accuracy: 0.5625 - val_loss: 0.5900
# Epoch 3/10
# 163/163 - 7s - 42ms/step - accuracy: 0.8848 - loss: 0.2715 - val_accuracy: 0.6250 - val_loss: 0.5679
# Epoch 4/10
# 163/163 - 7s - 42ms/step - accuracy: 0.9080 - loss: 0.2246 - val_accuracy: 0.6250 - val_loss: 0.5539
# Epoch 5/10
# 163/163 - 7s - 42ms/step - accuracy: 0.9164 - loss: 0.2068 - val_accuracy: 0.6250 - val_loss: 0.5507
# Epoch 6/10
# 163/163 - 7s - 42ms/step - accuracy: 0.9291 - loss: 0.1758 - val_accuracy: 0.6250 - val_loss: 0.5459
# Epoch 7/10
# 163/163 - 7s - 42ms/step - accuracy: 0.9275 - loss: 0.1764 - val_accuracy: 0.6875 - val_loss: 0.5318
# Epoch 8/10
# 163/163 - 7s - 42ms/step - accuracy: 0.9333 - loss: 0.1655 - val_accuracy: 0.6875 - val_loss: 0.5238
# Epoch 9/10
# 163/163 - 7s - 41ms/step - accuracy: 0.9406 - loss: 0.1483 - val_accuracy: 0.6875 - val_loss: 0.5402
# Epoch 10/10
# 163/163 - 7s - 42ms/step - accuracy: 0.9413 - loss: 0.1459 - val_accuracy: 0.6875 - val_loss: 0.5211
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 295ms/step
#
# ✅ Test Accuracy: 0.7901
# 🎯 Test F1 Score: 0.8536
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.93      0.47      0.63       234
#    PNEUMONIA       0.76      0.98      0.85       390
#
#     accuracy                           0.79       624
#    macro avg       0.84      0.73      0.74       624
# weighted avg       0.82      0.79      0.77       624
